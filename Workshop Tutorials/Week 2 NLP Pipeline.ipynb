# %% [markdown]
# ## Exploring NLP Pipeline (Part 1)
#
# Here are the 8 stages of NLP PIPLINE
#
# - Data Acquisition,
# - Text Extractiong & Cleaning,
# - Pre-Processing,
# - Feature Engineering,
# - Modelling,
# - Evaluation
# - Deployment
# - Monitoring and Model Updating

# %%
import nltk
import pandas as pd
import re
import contractions
from nltk.corpus import stopwords
from itertools import chain
from collections import Counter
from string import punctuation
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize, sent_tokenize

# %% [markdown]
# ## Twitter Sentiment Analysis
# With all of the tweets circulating every second, it is hard to tell whether the sentiment behind a specific tweet will impact a company, or a person's, brand for being viral (positive), or devastate profit because it strikes a negative tone. Capturing sentiment in the language is important in these times where decisions and reactions are created and updated in seconds. In this workshop, we'll create an NLP pipeline to predict the sentiment of each tweet.

# %% [markdown]
# ## Data acquisition
# In order to do any type of NLP analysis one requires data to analyze. The twitter data can be collected using the twitter API (https://developer.twitter.com/en/docs/twitter-api). Twitter API is the official programmatic endpoint provided by Twitter. It allows developers to access the enormous amount of public data on Twitter that millions of users share daily.
#
# Tweepy (https://www.tweepy.org/) is an easy-to-use Python library for accessing the Twitter API. Its API class provides access to the RESTful methods of the Twitter API. We will skip the data acquisition process for this workshop in order to keep it short. However, you can develop the process of extracting tweets from Twitter API as an individual project for your portfolio.

# %% [markdown]
# ## Data extraction
# The second step in the NLP pipeline is extracting the text from its native form (such as pdf, image or html files).
#
# Our dataset is a CSV(Comma Separated Values) file that contains tweets data. Each row contains the text of a tweet and a sentiment label. We will use the Pandas library to read the CSV file and load data into a dataframe.
#
# A Pandas DataFrame is a 2 dimensional data structure, like a 2 dimensional array, or a table with rows and columns.

# %% [raw]
# ## Here is an example of how to import a file tru a link
# import requests
#
# url = "https://github.com/Ali-Alameer/NLP/raw/main/data/train_tweets.csv"
# file_name = "train_tweets.csv"
#
# response = requests.get(url)
#
# if response.status_code == 200:
#     with open(file_name, 'wb') as file:
#         file.write(response.content)
#     print(f"File '{file_name}' downloaded successfully.")
# else:
#     print(f"Failed to download the file. Status code: {response.status_code}")

# %%
file_path = "/Users/Odera Nnaji/Downloads/Uni Note/NLP/week 2/train_tweets.csv"
file = pd.read_csv(file_path)

# %%
file.head()
# Out:
#    id  label                                              tweet
# 0   1      0   @user when a father is dysfunctional and is s...
# 1   2      0  @user @user thanks for #lyft credit i can't us...
# 2   3      0                                bihday your majesty
# 3   4      0  #model   i love u take with u all the time in ...
# 4   5      0             factsguide: society now    #motivation

# %%
file.columns
# Out:
# Index(['id', 'label', 'tweet'], dtype='object')

# %%
file.isnull().sum()
# Out:
# id       0
# label    0
# tweet    0
# dtype: int64

# %%
len(file)
# Out:
# 31962

# %%
file.describe()
# Out:
#                  id         label
# count  31962.000000  31962.000000
# mean   15981.500000      0.070146
# std     9226.778988      0.255397
# min        1.000000      0.000000
# 25%     7991.250000      0.000000
# 50%    15981.500000      0.000000
# 75%    23971.750000      0.000000
# max    31962.000000      1.000000

# %%
file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31962 entries, 0 to 31961
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      31962 non-null  int64
#  1   label   31962 non-null  int64
#  2   tweet   31962 non-null  object
# dtypes: int64(2), object(1)
# memory usage: 749.2+ KB

# %%
train_df = file[['tweet', 'label']]
train_df.columns = ['tweet', 'sentiment']

# %% [markdown]
# We can count the number of positive and negative tweets using the value_counts() method of a dataframe object.

# %%
train_df.sentiment.value_counts()
# Out:
# sentiment
# 0    29720
# 1     2242
# Name: count, dtype: int64

# %%
train_df.head()
# Out:
#                                                tweet  sentiment
# 0   @user when a father is dysfunctional and is s...          0
# 1  @user @user thanks for #lyft credit i can't us...          0
# 2                                bihday your majesty          0
# 3  #model   i love u take with u all the time in ...          0
# 4             factsguide: society now    #motivation          0

# %% [markdown]
# The dataset description indicates that:
#
# - 0 ==> positive sentiments
# - 1 ==> negative sentiments
#
# According to the result of the previous cell, there are 29,720 positive tweets and 2,242 negative tweets in the training dataset. As a result, the training dataset is imbalanced since the data points are not equal for the two classes.
#
# For storing sentiments, a Python dictionary is an appropriate data structure.

# %%
map = {0: 'Positive', 1: 'Negative'}
train_df = file[['tweet', 'label']].copy()
train_df.columns = ['tweet', 'sentiment']
train_df['sentiment'] = train_df['sentiment'].map(map)

# %%
train_df.head(25)
# Out:
#                                                 tweet sentiment
# 0    @user when a father is dysfunctional and is s...  Positive
# 1   @user @user thanks for #lyft credit i can't us...  Positive
# 2                                 bihday your majesty  Positive
# 3   #model   i love u take with u all the time in ...  Positive
# 4              factsguide: society now    #motivation  Positive
# 5   [2/2] huge fan fare and big talking before the...  Positive
# 6    @user camping tomorrow @user @user @user @use...  Positive
# 7   the next school year is the year for exams.ð...  Positive
# 8   we won!!! love the land!!! #allin #cavs #champ...  Positive
# 9    @user @user welcome here !  i'm   it's so #gr...  Positive
# 10   â #ireland consumer price index (mom) climb...  Positive
# 11  we are so selfish. #orlando #standwithorlando ...  Positive
# 12  i get to see my daddy today!!   #80days #getti...  Positive
# 13  @user #cnn calls #michigan middle school 'buil...  Negative
# 14  no comment!  in #australia   #opkillingbay #se...  Negative
# 15  ouch...junior is angryð#got7 #junior #yugyo...  Positive
# 16  i am thankful for having a paner. #thankful #p...  Positive
# 17                             retweet if you agree!   Negative
# 18  its #friday! ð smiles all around via ig use...  Positive
# 19  as we all know, essential oils are not made of...  Positive
# 20  #euro2016 people blaming ha for conceded goal ...  Positive
# 21  sad little dude..   #badday #coneofshame #cats...  Positive
# 22  product of the day: happy man #wine tool  who'...  Positive
# 23    @user @user lumpy says i am a . prove it lumpy.  Negative
# 24   @user #tgif   #ff to my #gamedev #indiedev #i...  Positive

# %% [markdown]
# ## Text cleaning & pre-processing
# Why Do We Need to clean and pre-process Text?
#
# - Extracting plain text: Textual data can come from a wide variety of sources: the web, PDFs, word documents, speech recognition systems, book scans, etc. Your goal is to extract plain text that is free of any source specific markup or constructs that are not relevant to your task.
#
# - Reducing complexity: Some features of our language like capitalization, punctuation, and common words such as a, of, and the, often help provide structure, but don't add much meaning. Sometimes it's best to remove them if that helps reduce the complexity of the procedures you want to apply later.
# In order to clean the text of tweets, we will first create a function that lowercase text, expand contractions, removes text enclosed in square brackets, removes links, removes punctuation, and removes words containing numbers.

# %%
def clean_text(text):
    # make text lowercase    
    text = str(text).lower()
    # expand contractions
    text = " ".join([contractions.fix(expanded_word) for expanded_word in text.split()])
    # remove text in square brackets
    text = re.sub(r'\[.*?\]', '', text)
    # remove links
    text = re.sub(r'https?://\S+|www\.\S+', '', text)
    text = re.sub(r'<.*?>+', '', text)
    # remove punctuation
    text = re.sub(r'[%s]' % re.escape(punctuation), '', text)
    # remove new lines
    text = re.sub(r'\n', '', text)
    # remove words containing numbers
    text = re.sub(r'\w*\d\w*', '', text)
    return text

# %%
train_df.head(20)
# Out:
#                                                 tweet sentiment
# 0    @user when a father is dysfunctional and is s...  Positive
# 1   @user @user thanks for #lyft credit i can't us...  Positive
# 2                                 bihday your majesty  Positive
# 3   #model   i love u take with u all the time in ...  Positive
# 4              factsguide: society now    #motivation  Positive
# 5   [2/2] huge fan fare and big talking before the...  Positive
# 6    @user camping tomorrow @user @user @user @use...  Positive
# 7   the next school year is the year for exams.ð...  Positive
# 8   we won!!! love the land!!! #allin #cavs #champ...  Positive
# 9    @user @user welcome here !  i'm   it's so #gr...  Positive
# 10   â #ireland consumer price index (mom) climb...  Positive
# 11  we are so selfish. #orlando #standwithorlando ...  Positive
# 12  i get to see my daddy today!!   #80days #getti...  Positive
# 13  @user #cnn calls #michigan middle school 'buil...  Negative
# 14  no comment!  in #australia   #opkillingbay #se...  Negative
# 15  ouch...junior is angryð#got7 #junior #yugyo...  Positive
# 16  i am thankful for having a paner. #thankful #p...  Positive
# 17                             retweet if you agree!   Negative
# 18  its #friday! ð smiles all around via ig use...  Positive
# 19  as we all know, essential oils are not made of...  Positive

# %%
train_df['clean_tweet'] = train_df['tweet'].apply(clean_text)

# %%
train_df.head(20)
# Out:
#                                                 tweet sentiment  \
# 0    @user when a father is dysfunctional and is s...  Positive
# 1   @user @user thanks for #lyft credit i can't us...  Positive
# 2                                 bihday your majesty  Positive
# 3   #model   i love u take with u all the time in ...  Positive
# 4              factsguide: society now    #motivation  Positive
# 5   [2/2] huge fan fare and big talking before the...  Positive
# 6    @user camping tomorrow @user @user @user @use...  Positive
# 7   the next school year is the year for exams.ð...  Positive
# 8   we won!!! love the land!!! #allin #cavs #champ...  Positive
# 9    @user @user welcome here !  i'm   it's so #gr...  Positive
# 10   â #ireland consumer price index (mom) climb...  Positive
# 11  we are so selfish. #orlando #standwithorlando ...  Positive
# 12  i get to see my daddy today!!   #80days #getti...  Positive
# 13  @user #cnn calls #michigan middle school 'buil...  Negative
# 14  no comment!  in #australia   #opkillingbay #se...  Negative
# 15  ouch...junior is angryð#got7 #junior #yugyo...  Positive
# 16  i am thankful for having a paner. #thankful #p...  Positive
# 17                             retweet if you agree!   Negative
# 18  its #friday! ð smiles all around via ig use...  Positive
# 19  as we all know, essential oils are not made of...  Positive
#
#                                           clean_tweet
# 0   user when a father is dysfunctional and is so ...
# 1   user user thanks for lyft credit i cannot use ...
# 2                                 bihday your majesty
# 3   model i love you take with you all the time in...
# 4                   factsguide society now motivation
# 5    huge fan fare and big talking before they lea...
# 6   user camping tomorrow user user user user user...
# 7   the next school year is the year for examsð¯...
# 8   we won love the land allin cavs champions clev...
# 9             user user welcome here  i am it is so
# 10  â ireland consumer price index mom climbed f...
# 11  we are so selfish orlando standwithorlando pul...
# 12            i get to see my daddy today  gettingfed
# 13  user cnn calls michigan middle school build th...
# 14  no comment in australia opkillingbay seashephe...
# 15         ouchjunior is angryð junior yugyoem omg
# 16  i am thankful for having a paner thankful posi...
# 17                               retweet if you agree
# 18  its friday ð smiles all around via ig user ...
# 19  as we all know essential oils are not made of ...

# %% [markdown]
#                                                         OR

# %%
 train_df['clean_tweet'] = train_df['tweet'].apply(lambda x: clean_text(x))

# %%
train_df.head(20)
# Out:
#                                                 tweet sentiment  \
# 0    @user when a father is dysfunctional and is s...  Positive
# 1   @user @user thanks for #lyft credit i can't us...  Positive
# 2                                 bihday your majesty  Positive
# 3   #model   i love u take with u all the time in ...  Positive
# 4              factsguide: society now    #motivation  Positive
# 5   [2/2] huge fan fare and big talking before the...  Positive
# 6    @user camping tomorrow @user @user @user @use...  Positive
# 7   the next school year is the year for exams.ð...  Positive
# 8   we won!!! love the land!!! #allin #cavs #champ...  Positive
# 9    @user @user welcome here !  i'm   it's so #gr...  Positive
# 10   â #ireland consumer price index (mom) climb...  Positive
# 11  we are so selfish. #orlando #standwithorlando ...  Positive
# 12  i get to see my daddy today!!   #80days #getti...  Positive
# 13  @user #cnn calls #michigan middle school 'buil...  Negative
# 14  no comment!  in #australia   #opkillingbay #se...  Negative
# 15  ouch...junior is angryð#got7 #junior #yugyo...  Positive
# 16  i am thankful for having a paner. #thankful #p...  Positive
# 17                             retweet if you agree!   Negative
# 18  its #friday! ð smiles all around via ig use...  Positive
# 19  as we all know, essential oils are not made of...  Positive
#
#                                           clean_tweet
# 0   user when a father is dysfunctional and is so ...
# 1   user user thanks for lyft credit i cannot use ...
# 2                                 bihday your majesty
# 3   model i love you take with you all the time in...
# 4                   factsguide society now motivation
# 5    huge fan fare and big talking before they lea...
# 6   user camping tomorrow user user user user user...
# 7   the next school year is the year for examsð¯...
# 8   we won love the land allin cavs champions clev...
# 9             user user welcome here  i am it is so
# 10  â ireland consumer price index mom climbed f...
# 11  we are so selfish orlando standwithorlando pul...
# 12            i get to see my daddy today  gettingfed
# 13  user cnn calls michigan middle school build th...
# 14  no comment in australia opkillingbay seashephe...
# 15         ouchjunior is angryð junior yugyoem omg
# 16  i am thankful for having a paner thankful posi...
# 17                               retweet if you agree
# 18  its friday ð smiles all around via ig user ...
# 19  as we all know essential oils are not made of ...

# %% [markdown]
# Complete the following code to create a column named "no_sentences" containing the number of sentences for each tweet.

# %%
def len_sentence(text):
    return len(sent_tokenize(text))

# %%
train_df['no_sentence'] = train_df['tweet'].apply(len_sentence)

# %%
train_df.head()
# Out:
#                                                tweet sentiment  \
# 0   @user when a father is dysfunctional and is s...  Positive
# 1  @user @user thanks for #lyft credit i can't us...  Positive
# 2                                bihday your majesty  Positive
# 3  #model   i love u take with u all the time in ...  Positive
# 4             factsguide: society now    #motivation  Positive
#
#                                          clean_tweet  no_sentence
# 0  user when a father is dysfunctional and is so ...            2
# 1  user user thanks for lyft credit i cannot use ...            2
# 2                                bihday your majesty            1
# 3  model i love you take with you all the time in...            2
# 4                  factsguide society now motivation            1

# %% [markdown]
#                                             OR

# %%
train_df['no_sentence'] = train_df['tweet'].apply(lambda x: len(sent_tokenize(x)))

# %%
train_df.head()
# Out:
#                                                tweet sentiment  \
# 0   @user when a father is dysfunctional and is s...  Positive
# 1  @user @user thanks for #lyft credit i can't us...  Positive
# 2                                bihday your majesty  Positive
# 3  #model   i love u take with u all the time in ...  Positive
# 4             factsguide: society now    #motivation  Positive
#
#                                          clean_tweet  no_sentence
# 0  user when a father is dysfunctional and is so ...            2
# 1  user user thanks for lyft credit i cannot use ...            2
# 2                                bihday your majesty            1
# 3  model i love you take with you all the time in...            2
# 4                  factsguide society now motivation            1

# %% [markdown]
# ## Word tokenization
# Now we can tokenize tweets into words and extract a list of words for each tweet. We can use the NLTK word tokenizer

# %%
def word_token(text):
    return word_tokenize(text)

# %%
train_df['word_list'] = train_df['clean_tweet'].apply(word_tokenize)

# %%
train_df.head(20)
# Out:
#                                                 tweet sentiment  \
# 0    @user when a father is dysfunctional and is s...  Positive
# 1   @user @user thanks for #lyft credit i can't us...  Positive
# 2                                 bihday your majesty  Positive
# 3   #model   i love u take with u all the time in ...  Positive
# 4              factsguide: society now    #motivation  Positive
# 5   [2/2] huge fan fare and big talking before the...  Positive
# 6    @user camping tomorrow @user @user @user @use...  Positive
# 7   the next school year is the year for exams.ð...  Positive
# 8   we won!!! love the land!!! #allin #cavs #champ...  Positive
# 9    @user @user welcome here !  i'm   it's so #gr...  Positive
# 10   â #ireland consumer price index (mom) climb...  Positive
# 11  we are so selfish. #orlando #standwithorlando ...  Positive
# 12  i get to see my daddy today!!   #80days #getti...  Positive
# 13  @user #cnn calls #michigan middle school 'buil...  Negative
# 14  no comment!  in #australia   #opkillingbay #se...  Negative
# 15  ouch...junior is angryð#got7 #junior #yugyo...  Positive
# 16  i am thankful for having a paner. #thankful #p...  Positive
# 17                             retweet if you agree!   Negative
# 18  its #friday! ð smiles all around via ig use...  Positive
# 19  as we all know, essential oils are not made of...  Positive
#
#                                           clean_tweet  no_sentence  \
# 0   user when a father is dysfunctional and is so ...            2
# 1   user user thanks for lyft credit i cannot use ...            2
# 2                                 bihday your majesty            1
# 3   model i love you take with you all the time in...            2
# 4                   factsguide society now motivation            1
# 5    huge fan fare and big talking before they lea...            3
# 6   user camping tomorrow user user user user user...            1
# 7   the next school year is the year for examsð¯...            1
# 8   we won love the land allin cavs champions clev...            3
# 9             user user welcome here  i am it is so              2
# 10  â ireland consumer price index mom climbed f...            1
# 11  we are so selfish orlando standwithorlando pul...            2
# 12            i get to see my daddy today  gettingfed            2
# 13  user cnn calls michigan middle school build th...            1
# 14  no comment in australia opkillingbay seashephe...            2
# 15         ouchjunior is angryð junior yugyoem omg            1
# 16  i am thankful for having a paner thankful posi...            2
# 17                               retweet if you agree            1
# 18  its friday ð smiles all around via ig user ...            2
# 19  as we all know essential oils are not made of ...            1
#
#                                             word_list
# 0   [user, when, a, father, is, dysfunctional, and...
# 1   [user, user, thanks, for, lyft, credit, i, can...
# 2                             [bihday, your, majesty]
# 3   [model, i, love, you, take, with, you, all, th...
# 4              [factsguide, society, now, motivation]
# 5   [huge, fan, fare, and, big, talking, before, t...
# 6   [user, camping, tomorrow, user, user, user, us...
# 7   [the, next, school, year, is, the, year, for, ...
# 8   [we, won, love, the, land, allin, cavs, champi...
# 9      [user, user, welcome, here, i, am, it, is, so]
# 10  [â, ireland, consumer, price, index, mom, cl...
# 11  [we, are, so, selfish, orlando, standwithorlan...
# 12    [i, get, to, see, my, daddy, today, gettingfed]
# 13  [user, cnn, calls, michigan, middle, school, b...
# 14  [no, comment, in, australia, opkillingbay, sea...
# 15  [ouchjunior, is, angryð, junior, yugyoem, omg]
# 16  [i, am, thankful, for, having, a, paner, thank...
# 17                          [retweet, if, you, agree]
# 18  [its, friday, ð, smiles, all, around, via, ...
# 19  [as, we, all, know, essential, oils, are, not,...

# %% [markdown]
#                                               OR

# %%
train_df['word_list'] = train_df['clean_tweet'].apply(lambda x: word_tokenize(x))

# %%
train_df.head()
# Out:
#                                                tweet sentiment  \
# 0   @user when a father is dysfunctional and is s...  Positive
# 1  @user @user thanks for #lyft credit i can't us...  Positive
# 2                                bihday your majesty  Positive
# 3  #model   i love u take with u all the time in ...  Positive
# 4             factsguide: society now    #motivation  Positive
#
#                                          clean_tweet  no_sentence  \
# 0  user when a father is dysfunctional and is so ...            2
# 1  user user thanks for lyft credit i cannot use ...            2
# 2                                bihday your majesty            1
# 3  model i love you take with you all the time in...            2
# 4                  factsguide society now motivation            1
#
#                                            word_list
# 0  [user, when, a, father, is, dysfunctional, and...
# 1  [user, user, thanks, for, lyft, credit, i, can...
# 2                            [bihday, your, majesty]
# 3  [model, i, love, you, take, with, you, all, th...
# 4             [factsguide, society, now, motivation]

# %% [markdown]
# ## Finding the most common words in tweets text
# Before removing stop words it is worth looking at the tweet's word list and extracting the most common words in tweet texts. This step will help us to understand why we need to remove stop words from the word list.
#
# In the "collections" module of python, you'll find a class specially designed to count several different objects in one go. This class is conveniently called Counter. We use the Counter class to count the number of repetitions of a word in the word list column and then we store the result in a new dataframe.

# %%
flattened_word = chain.from_iterable(train_df['word_list'])
top_word = Counter(flattened_word)
temp_df = pd.DataFrame(top_word.most_common(20), columns = ['Words', 'Counts'])
temp_df.style.background_gradient(cmap = 'gist_earth')
# Out:
# <style type="text/css">
# #T_26b48_row0_col1 {
#   background-color: #fdfbfb;
#   color: #000000;
# }
# #T_26b48_row1_col1 {
#   background-color: #64a24d;
#   color: #f1f1f1;
# }
# #T_26b48_row2_col1 {
#   background-color: #62a14c;
#   color: #f1f1f1;
# }
# #T_26b48_row3_col1 {
#   background-color: #37886e;
#   color: #f1f1f1;
# }
# #T_26b48_row4_col1 {
#   background-color: #358673;
#   color: #f1f1f1;
# }
# #T_26b48_row5_col1 {
#   background-color: #2d787f;
#   color: #f1f1f1;
# }
# #T_26b48_row6_col1 {
#   background-color: #29707e;
#   color: #f1f1f1;
# }
# #T_26b48_row7_col1 {
#   background-color: #1b4b7a;
#   color: #f1f1f1;
# }
# #T_26b48_row8_col1 {
#   background-color: #194379;
#   color: #f1f1f1;
# }
# #T_26b48_row9_col1 {
#   background-color: #173d79;
#   color: #f1f1f1;
# }
# #T_26b48_row10_col1 {
#   background-color: #133278;
#   color: #f1f1f1;
# }
# #T_26b48_row11_col1 {
#   background-color: #0e2076;
#   color: #f1f1f1;
# }
# #T_26b48_row12_col1 {
#   background-color: #0d1e76;
#   color: #f1f1f1;
# }
# #T_26b48_row13_col1 {
#   background-color: #0c1976;
#   color: #f1f1f1;
# }
# #T_26b48_row14_col1, #T_26b48_row15_col1, #T_26b48_row16_col1 {
#   background-color: #020043;
#   color: #f1f1f1;
# }
# #T_26b48_row17_col1 {
#   background-color: #010039;
#   color: #f1f1f1;
# }
# #T_26b48_row18_col1, #T_26b48_row19_col1 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_26b48">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_26b48_level0_col0" class="col_heading level0 col0" >Words</th>
#       <th id="T_26b48_level0_col1" class="col_heading level0 col1" >Counts</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_26b48_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_26b48_row0_col0" class="data row0 col0" >user</td>
#       <td id="T_26b48_row0_col1" class="data row0 col1" >17474</td>
#     </tr>
#     <tr>
#       <th id="T_26b48_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_26b48_row1_col0" class="data row1 col0" >the</td>
#       <td id="T_26b48_row1_col1" class="data row1 col1" >10156</td>
#     </tr>
#     <tr>
#       <th id="T_26b48_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_26b48_row2_col0" class="data row2 col0" >to</td>
#       <td id="T_26b48_row2_col1" class="data row2 col1" >10089</td>
#     </tr>
#     <tr>
#       <th id="T_26b48_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_26b48_row3_col0" class="data row3 col0" >you</td>
#       <td id="T_26b48_row3_col1" class="data row3 col1" >7510</td>
#     </tr>
#     <tr>
#       <th id="T_26b48_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_26b48_row4_col0" class="data row4 col0" >i</td>
#       <td id="T_26b48_row4_col1" class="data row4 col1" >7288</td>
#     </tr>
#     <tr>
#       <th id="T_26b48_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_26b48_row5_col0" class="data row5 col0" >a</td>
#       <td id="T_26b48_row5_col1" class="data row5 col1" >6416</td>
#     </tr>
#     <tr>
#       <th id="T_26b48_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_26b48_row6_col0" class="data row6 col0" >is</td>
#       <td id="T_26b48_row6_col1" class="data row6 col1" >6108</td>
#     </tr>
#     <tr>
#       <th id="T_26b48_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_26b48_row7_col0" class="data row7 col0" >and</td>
#       <td id="T_26b48_row7_col1" class="data row7 col1" >4871</td>
#     </tr>
#     <tr>
#       <th id="T_26b48_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_26b48_row8_col0" class="data row8 col0" >in</td>
#       <td id="T_26b48_row8_col1" class="data row8 col1" >4638</td>
#     </tr>
#     <tr>
#       <th id="T_26b48_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_26b48_row9_col0" class="data row9 col0" >for</td>
#       <td id="T_26b48_row9_col1" class="data row9 col1" >4479</td>
#     </tr>
#     <tr>
#       <th id="T_26b48_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_26b48_row10_col0" class="data row10 col0" >of</td>
#       <td id="T_26b48_row10_col1" class="data row10 col1" >4193</td>
#     </tr>
#     <tr>
#       <th id="T_26b48_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_26b48_row11_col0" class="data row11 col0" >not</td>
#       <td id="T_26b48_row11_col1" class="data row11 col1" >3726</td>
#     </tr>
#     <tr>
#       <th id="T_26b48_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_26b48_row12_col0" class="data row12 col0" >my</td>
#       <td id="T_26b48_row12_col1" class="data row12 col1" >3676</td>
#     </tr>
#     <tr>
#       <th id="T_26b48_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_26b48_row13_col0" class="data row13 col0" >it</td>
#       <td id="T_26b48_row13_col1" class="data row13 col1" >3549</td>
#     </tr>
#     <tr>
#       <th id="T_26b48_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_26b48_row14_col0" class="data row14 col0" >are</td>
#       <td id="T_26b48_row14_col1" class="data row14 col1" >2669</td>
#     </tr>
#     <tr>
#       <th id="T_26b48_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_26b48_row15_col0" class="data row15 col0" >love</td>
#       <td id="T_26b48_row15_col1" class="data row15 col1" >2668</td>
#     </tr>
#     <tr>
#       <th id="T_26b48_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_26b48_row16_col0" class="data row16 col0" >this</td>
#       <td id="T_26b48_row16_col1" class="data row16 col1" >2652</td>
#     </tr>
#     <tr>
#       <th id="T_26b48_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_26b48_row17_col0" class="data row17 col0" >on</td>
#       <td id="T_26b48_row17_col1" class="data row17 col1" >2629</td>
#     </tr>
#     <tr>
#       <th id="T_26b48_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_26b48_row18_col0" class="data row18 col0" >with</td>
#       <td id="T_26b48_row18_col1" class="data row18 col1" >2510</td>
#     </tr>
#     <tr>
#       <th id="T_26b48_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_26b48_row19_col0" class="data row19 col0" >be</td>
#       <td id="T_26b48_row19_col1" class="data row19 col1" >2460</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
#                                                 OR

# %% [raw]
# top = Counter([item for sublist in train_df['word_list'] for item in sublist])
# temp_df = pd.DataFrame(top.most_common(20))
# temp_df.columns = ['Common_words','count']
# temp_df.style.background_gradient(cmap = 'Blues')

# %% [markdown]
# ## Stop words removal
#
# As you can see, many of the most commonly used words are not useful for identifying tweet sentiment. They belong to the stop words list and should be removed from the tweets words list.

# %%
stopword = set(stopwords.words('english'))

# %%
def remove_stopwords(word_list):

    return [word for word in word_list if word not in stopword]

# %%
train_df['word_list_without_sw'] = train_df['word_list'].apply(remove_stopwords)

# %%
train_df.head(20)
# Out:
#                                                 tweet sentiment  \
# 0    @user when a father is dysfunctional and is s...  Positive
# 1   @user @user thanks for #lyft credit i can't us...  Positive
# 2                                 bihday your majesty  Positive
# 3   #model   i love u take with u all the time in ...  Positive
# 4              factsguide: society now    #motivation  Positive
# 5   [2/2] huge fan fare and big talking before the...  Positive
# 6    @user camping tomorrow @user @user @user @use...  Positive
# 7   the next school year is the year for exams.ð...  Positive
# 8   we won!!! love the land!!! #allin #cavs #champ...  Positive
# 9    @user @user welcome here !  i'm   it's so #gr...  Positive
# 10   â #ireland consumer price index (mom) climb...  Positive
# 11  we are so selfish. #orlando #standwithorlando ...  Positive
# 12  i get to see my daddy today!!   #80days #getti...  Positive
# 13  @user #cnn calls #michigan middle school 'buil...  Negative
# 14  no comment!  in #australia   #opkillingbay #se...  Negative
# 15  ouch...junior is angryð#got7 #junior #yugyo...  Positive
# 16  i am thankful for having a paner. #thankful #p...  Positive
# 17                             retweet if you agree!   Negative
# 18  its #friday! ð smiles all around via ig use...  Positive
# 19  as we all know, essential oils are not made of...  Positive
#
#                                           clean_tweet  no_sentence  \
# 0   user when a father is dysfunctional and is so ...            2
# 1   user user thanks for lyft credit i cannot use ...            2
# 2                                 bihday your majesty            1
# 3   model i love you take with you all the time in...            2
# 4                   factsguide society now motivation            1
# 5    huge fan fare and big talking before they lea...            3
# 6   user camping tomorrow user user user user user...            1
# 7   the next school year is the year for examsð¯...            1
# 8   we won love the land allin cavs champions clev...            3
# 9             user user welcome here  i am it is so              2
# 10  â ireland consumer price index mom climbed f...            1
# 11  we are so selfish orlando standwithorlando pul...            2
# 12            i get to see my daddy today  gettingfed            2
# 13  user cnn calls michigan middle school build th...            1
# 14  no comment in australia opkillingbay seashephe...            2
# 15         ouchjunior is angryð junior yugyoem omg            1
# 16  i am thankful for having a paner thankful posi...            2
# 17                               retweet if you agree            1
# 18  its friday ð smiles all around via ig user ...            2
# 19  as we all know essential oils are not made of ...            1
#
#                                             word_list  \
# 0   [user, when, a, father, is, dysfunctional, and...
# 1   [user, user, thanks, for, lyft, credit, i, can...
# 2                             [bihday, your, majesty]
# 3   [model, i, love, you, take, with, you, all, th...
# 4              [factsguide, society, now, motivation]
# 5   [huge, fan, fare, and, big, talking, before, t...
# 6   [user, camping, tomorrow, user, user, user, us...
# 7   [the, next, school, year, is, the, year, for, ...
# 8   [we, won, love, the, land, allin, cavs, champi...
# 9      [user, user, welcome, here, i, am, it, is, so]
# 10  [â, ireland, consumer, price, index, mom, cl...
# 11  [we, are, so, selfish, orlando, standwithorlan...
# 12    [i, get, to, see, my, daddy, today, gettingfed]
# 13  [user, cnn, calls, michigan, middle, school, b...
# 14  [no, comment, in, australia, opkillingbay, sea...
# 15  [ouchjunior, is, angryð, junior, yugyoem, omg]
# 16  [i, am, thankful, for, having, a, paner, thank...
# 17                          [retweet, if, you, agree]
# 18  [its, friday, ð, smiles, all, around, via, ...
# 19  [as, we, all, know, essential, oils, are, not,...
#
#                                  word_list_without_sw
# 0   [user, father, dysfunctional, selfish, drags, ...
# 1   [user, user, thanks, lyft, credit, use, offer,...
# 2                                   [bihday, majesty]
# 3   [model, love, take, time, areð±, ððð...
# 4                   [factsguide, society, motivation]
# 5   [huge, fan, fare, big, talking, leave, chaos, ...
# 6   [user, camping, tomorrow, user, user, user, us...
# 7   [next, school, year, year, examsð¯, think, ð...
# 8   [love, land, allin, cavs, champions, cleveland...
# 9                               [user, user, welcome]
# 10  [â, ireland, consumer, price, index, mom, cl...
# 11  [selfish, orlando, standwithorlando, pulseshoo...
# 12               [get, see, daddy, today, gettingfed]
# 13  [user, cnn, calls, michigan, middle, school, b...
# 14  [comment, australia, opkillingbay, seashepherd...
# 15      [ouchjunior, angryð, junior, yugyoem, omg]
# 16              [thankful, paner, thankful, positive]
# 17                                   [retweet, agree]
# 18  [friday, ð, smiles, around, via, ig, user, ...
# 19           [know, essential, oils, made, chemicals]

# %% [markdown]
#                                                             OR

# %%
train_df['word_list_without_sw'] = train_df['word_list'].apply(lambda x: remove_stopwords(x))

# %%
train_df.head()
# Out:
#                                                tweet sentiment  \
# 0   @user when a father is dysfunctional and is s...  Positive
# 1  @user @user thanks for #lyft credit i can't us...  Positive
# 2                                bihday your majesty  Positive
# 3  #model   i love u take with u all the time in ...  Positive
# 4             factsguide: society now    #motivation  Positive
#
#                                          clean_tweet  no_sentence  \
# 0  user when a father is dysfunctional and is so ...            2
# 1  user user thanks for lyft credit i cannot use ...            2
# 2                                bihday your majesty            1
# 3  model i love you take with you all the time in...            2
# 4                  factsguide society now motivation            1
#
#                                            word_list  \
# 0  [user, when, a, father, is, dysfunctional, and...
# 1  [user, user, thanks, for, lyft, credit, i, can...
# 2                            [bihday, your, majesty]
# 3  [model, i, love, you, take, with, you, all, th...
# 4             [factsguide, society, now, motivation]
#
#                                 word_list_without_sw
# 0  [user, father, dysfunctional, selfish, drags, ...
# 1  [user, user, thanks, lyft, credit, use, offer,...
# 2                                  [bihday, majesty]
# 3  [model, love, take, time, areð±, ððð...
# 4                  [factsguide, society, motivation]

# %%
flat_words  = chain.from_iterable(train_df['word_list_without_sw'])
Top = Counter(flat_words)
tempdf = pd.DataFrame(Top.most_common(20), columns = ['Words', 'Count'])
tempdf.style.background_gradient(cmap = 'Purples')
# Out:
# <style type="text/css">
# #T_81197_row0_col1 {
#   background-color: #3f007d;
#   color: #f1f1f1;
# }
# #T_81197_row1_col1 {
#   background-color: #f0eef6;
#   color: #000000;
# }
# #T_81197_row2_col1 {
#   background-color: #f3f1f7;
#   color: #000000;
# }
# #T_81197_row3_col1 {
#   background-color: #f6f5f9;
#   color: #000000;
# }
# #T_81197_row4_col1 {
#   background-color: #f7f5fa;
#   color: #000000;
# }
# #T_81197_row5_col1 {
#   background-color: #faf8fb;
#   color: #000000;
# }
# #T_81197_row6_col1, #T_81197_row7_col1, #T_81197_row8_col1, #T_81197_row9_col1, #T_81197_row10_col1 {
#   background-color: #faf9fc;
#   color: #000000;
# }
# #T_81197_row11_col1, #T_81197_row12_col1, #T_81197_row13_col1, #T_81197_row14_col1, #T_81197_row15_col1 {
#   background-color: #fbfafc;
#   color: #000000;
# }
# #T_81197_row16_col1, #T_81197_row17_col1, #T_81197_row18_col1, #T_81197_row19_col1 {
#   background-color: #fcfbfd;
#   color: #000000;
# }
# </style>
# <table id="T_81197">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_81197_level0_col0" class="col_heading level0 col0" >Words</th>
#       <th id="T_81197_level0_col1" class="col_heading level0 col1" >Count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_81197_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_81197_row0_col0" class="data row0 col0" >user</td>
#       <td id="T_81197_row0_col1" class="data row0 col1" >17474</td>
#     </tr>
#     <tr>
#       <th id="T_81197_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_81197_row1_col0" class="data row1 col0" >love</td>
#       <td id="T_81197_row1_col1" class="data row1 col1" >2668</td>
#     </tr>
#     <tr>
#       <th id="T_81197_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_81197_row2_col0" class="data row2 col0" >day</td>
#       <td id="T_81197_row2_col1" class="data row2 col1" >2198</td>
#     </tr>
#     <tr>
#       <th id="T_81197_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_81197_row3_col0" class="data row3 col0" >happy</td>
#       <td id="T_81197_row3_col1" class="data row3 col1" >1663</td>
#     </tr>
#     <tr>
#       <th id="T_81197_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_81197_row4_col0" class="data row4 col0" >amp</td>
#       <td id="T_81197_row4_col1" class="data row4 col1" >1582</td>
#     </tr>
#     <tr>
#       <th id="T_81197_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_81197_row5_col0" class="data row5 col0" >time</td>
#       <td id="T_81197_row5_col1" class="data row5 col1" >1110</td>
#     </tr>
#     <tr>
#       <th id="T_81197_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_81197_row6_col0" class="data row6 col0" >life</td>
#       <td id="T_81197_row6_col1" class="data row6 col1" >1086</td>
#     </tr>
#     <tr>
#       <th id="T_81197_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_81197_row7_col0" class="data row7 col0" >like</td>
#       <td id="T_81197_row7_col1" class="data row7 col1" >1042</td>
#     </tr>
#     <tr>
#       <th id="T_81197_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_81197_row8_col0" class="data row8 col0" >â¦</td>
#       <td id="T_81197_row8_col1" class="data row8 col1" >1004</td>
#     </tr>
#     <tr>
#       <th id="T_81197_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_81197_row9_col0" class="data row9 col0" >today</td>
#       <td id="T_81197_row9_col1" class="data row9 col1" >991</td>
#     </tr>
#     <tr>
#       <th id="T_81197_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_81197_row10_col0" class="data row10 col0" >new</td>
#       <td id="T_81197_row10_col1" class="data row10 col1" >983</td>
#     </tr>
#     <tr>
#       <th id="T_81197_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_81197_row11_col0" class="data row11 col0" >people</td>
#       <td id="T_81197_row11_col1" class="data row11 col1" >950</td>
#     </tr>
#     <tr>
#       <th id="T_81197_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_81197_row12_col0" class="data row12 col0" >positive</td>
#       <td id="T_81197_row12_col1" class="data row12 col1" >928</td>
#     </tr>
#     <tr>
#       <th id="T_81197_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_81197_row13_col0" class="data row13 col0" >thankful</td>
#       <td id="T_81197_row13_col1" class="data row13 col1" >919</td>
#     </tr>
#     <tr>
#       <th id="T_81197_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_81197_row14_col0" class="data row14 col0" >get</td>
#       <td id="T_81197_row14_col1" class="data row14 col1" >917</td>
#     </tr>
#     <tr>
#       <th id="T_81197_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_81197_row15_col0" class="data row15 col0" >good</td>
#       <td id="T_81197_row15_col1" class="data row15 col1" >840</td>
#     </tr>
#     <tr>
#       <th id="T_81197_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_81197_row16_col0" class="data row16 col0" >bihday</td>
#       <td id="T_81197_row16_col1" class="data row16 col1" >825</td>
#     </tr>
#     <tr>
#       <th id="T_81197_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_81197_row17_col0" class="data row17 col0" >one</td>
#       <td id="T_81197_row17_col1" class="data row17 col1" >781</td>
#     </tr>
#     <tr>
#       <th id="T_81197_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_81197_row18_col0" class="data row18 col0" >see</td>
#       <td id="T_81197_row18_col1" class="data row18 col1" >756</td>
#     </tr>
#     <tr>
#       <th id="T_81197_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_81197_row19_col0" class="data row19 col0" >fathers</td>
#       <td id="T_81197_row19_col1" class="data row19 col1" >706</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Most common words sentiments wise
# As a result of this process, we can see some meaningful words among the most common words. As we have more positive tweets in our dataset, positive words have a larger proportion. We can check the most common word in both negative and positive tweets separately. In the following cell, we will create two separate dataframes for each sentiment and repeat the above process.

# %%
# create seperate dataframes for each sentiment
Positive_sentiment = train_df[train_df['sentiment'] == 'Positive']
Negative_sentiment = train_df[train_df['sentiment'] == 'Negative']

# %%
positive_sent = Positive_sentiment['word_list_without_sw']
flat_word = chain.from_iterable(positive_sent)
topwords = Counter(flat_word)
tmpdf = pd.DataFrame(topwords.most_common(20), columns = ['Words', 'Counts'])
tmpdf = tmpdf.iloc[1:,:]
tmpdf.style.background_gradient(cmap = 'Reds')
# Out:
# <style type="text/css">
# #T_baf58_row0_col1 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_baf58_row1_col1 {
#   background-color: #c5171c;
#   color: #f1f1f1;
# }
# #T_baf58_row2_col1 {
#   background-color: #fb6d4d;
#   color: #f1f1f1;
# }
# #T_baf58_row3_col1 {
#   background-color: #fca689;
#   color: #000000;
# }
# #T_baf58_row4_col1 {
#   background-color: #fdcbb6;
#   color: #000000;
# }
# #T_baf58_row5_col1 {
#   background-color: #fdccb8;
#   color: #000000;
# }
# #T_baf58_row6_col1 {
#   background-color: #fedbcc;
#   color: #000000;
# }
# #T_baf58_row7_col1 {
#   background-color: #fee2d5;
#   color: #000000;
# }
# #T_baf58_row8_col1 {
#   background-color: #fee3d6;
#   color: #000000;
# }
# #T_baf58_row9_col1 {
#   background-color: #fee3d7;
#   color: #000000;
# }
# #T_baf58_row10_col1 {
#   background-color: #fee4d8;
#   color: #000000;
# }
# #T_baf58_row11_col1 {
#   background-color: #fee6da;
#   color: #000000;
# }
# #T_baf58_row12_col1 {
#   background-color: #fee8de;
#   color: #000000;
# }
# #T_baf58_row13_col1, #T_baf58_row14_col1 {
#   background-color: #ffebe2;
#   color: #000000;
# }
# #T_baf58_row15_col1 {
#   background-color: #ffece4;
#   color: #000000;
# }
# #T_baf58_row16_col1, #T_baf58_row17_col1 {
#   background-color: #fff3ed;
#   color: #000000;
# }
# #T_baf58_row18_col1 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_baf58">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_baf58_level0_col0" class="col_heading level0 col0" >Words</th>
#       <th id="T_baf58_level0_col1" class="col_heading level0 col1" >Counts</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_baf58_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_baf58_row0_col0" class="data row0 col0" >love</td>
#       <td id="T_baf58_row0_col1" class="data row0 col1" >2643</td>
#     </tr>
#     <tr>
#       <th id="T_baf58_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_baf58_row1_col0" class="data row1 col0" >day</td>
#       <td id="T_baf58_row1_col1" class="data row1 col1" >2190</td>
#     </tr>
#     <tr>
#       <th id="T_baf58_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_baf58_row2_col0" class="data row2 col0" >happy</td>
#       <td id="T_baf58_row2_col1" class="data row2 col1" >1651</td>
#     </tr>
#     <tr>
#       <th id="T_baf58_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_baf58_row3_col0" class="data row3 col0" >amp</td>
#       <td id="T_baf58_row3_col1" class="data row3 col1" >1314</td>
#     </tr>
#     <tr>
#       <th id="T_baf58_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_baf58_row4_col0" class="data row4 col0" >time</td>
#       <td id="T_baf58_row4_col1" class="data row4 col1" >1088</td>
#     </tr>
#     <tr>
#       <th id="T_baf58_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_baf58_row5_col0" class="data row5 col0" >life</td>
#       <td id="T_baf58_row5_col1" class="data row5 col1" >1080</td>
#     </tr>
#     <tr>
#       <th id="T_baf58_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_baf58_row6_col0" class="data row6 col0" >today</td>
#       <td id="T_baf58_row6_col1" class="data row6 col1" >979</td>
#     </tr>
#     <tr>
#       <th id="T_baf58_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_baf58_row7_col0" class="data row7 col0" >positive</td>
#       <td id="T_baf58_row7_col1" class="data row7 col1" >925</td>
#     </tr>
#     <tr>
#       <th id="T_baf58_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_baf58_row8_col0" class="data row8 col0" >thankful</td>
#       <td id="T_baf58_row8_col1" class="data row8 col1" >919</td>
#     </tr>
#     <tr>
#       <th id="T_baf58_level0_row9" class="row_heading level0 row9" >10</th>
#       <td id="T_baf58_row9_col0" class="data row9 col0" >new</td>
#       <td id="T_baf58_row9_col1" class="data row9 col1" >914</td>
#     </tr>
#     <tr>
#       <th id="T_baf58_level0_row10" class="row_heading level0 row10" >11</th>
#       <td id="T_baf58_row10_col0" class="data row10 col0" >like</td>
#       <td id="T_baf58_row10_col1" class="data row10 col1" >905</td>
#     </tr>
#     <tr>
#       <th id="T_baf58_level0_row11" class="row_heading level0 row11" >12</th>
#       <td id="T_baf58_row11_col0" class="data row11 col0" >get</td>
#       <td id="T_baf58_row11_col1" class="data row11 col1" >883</td>
#     </tr>
#     <tr>
#       <th id="T_baf58_level0_row12" class="row_heading level0 row12" >13</th>
#       <td id="T_baf58_row12_col0" class="data row12 col0" >people</td>
#       <td id="T_baf58_row12_col1" class="data row12 col1" >851</td>
#     </tr>
#     <tr>
#       <th id="T_baf58_level0_row13" class="row_heading level0 row13" >14</th>
#       <td id="T_baf58_row13_col0" class="data row13 col0" >bihday</td>
#       <td id="T_baf58_row13_col1" class="data row13 col1" >825</td>
#     </tr>
#     <tr>
#       <th id="T_baf58_level0_row14" class="row_heading level0 row14" >15</th>
#       <td id="T_baf58_row14_col0" class="data row14 col0" >â¦</td>
#       <td id="T_baf58_row14_col1" class="data row14 col1" >823</td>
#     </tr>
#     <tr>
#       <th id="T_baf58_level0_row15" class="row_heading level0 row15" >16</th>
#       <td id="T_baf58_row15_col0" class="data row15 col0" >good</td>
#       <td id="T_baf58_row15_col1" class="data row15 col1" >807</td>
#     </tr>
#     <tr>
#       <th id="T_baf58_level0_row16" class="row_heading level0 row16" >17</th>
#       <td id="T_baf58_row16_col0" class="data row16 col0" >one</td>
#       <td id="T_baf58_row16_col1" class="data row16 col1" >733</td>
#     </tr>
#     <tr>
#       <th id="T_baf58_level0_row17" class="row_heading level0 row17" >18</th>
#       <td id="T_baf58_row17_col0" class="data row17 col0" >see</td>
#       <td id="T_baf58_row17_col1" class="data row17 col1" >731</td>
#     </tr>
#     <tr>
#       <th id="T_baf58_level0_row18" class="row_heading level0 row18" >19</th>
#       <td id="T_baf58_row18_col0" class="data row18 col0" >fathers</td>
#       <td id="T_baf58_row18_col1" class="data row18 col1" >704</td>
#     </tr>
#   </tbody>
# </table>

# %%
negative_sent = Negative_sentiment['word_list_without_sw']
fflatwords = chain.from_iterable(negative_sent)
topwording = Counter(fflatwords)
tmpdfs = pd.DataFrame(topwording.most_common(20), columns= ['Words', 'Counts'])
tmpdfs = tmpdfs.iloc[1:,:]
tmpdfs.style.background_gradient(cmap = 'nipy_spectral_r')
# Out:
# <style type="text/css">
# #T_89d6a_row0_col1 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_89d6a_row1_col1 {
#   background-color: #00aaab;
#   color: #f1f1f1;
# }
# #T_89d6a_row2_col1 {
#   background-color: #00a13d;
#   color: #f1f1f1;
# }
# #T_89d6a_row3_col1 {
#   background-color: #00f700;
#   color: #000000;
# }
# #T_89d6a_row4_col1, #T_89d6a_row5_col1 {
#   background-color: #b0ff00;
#   color: #000000;
# }
# #T_89d6a_row6_col1 {
#   background-color: #d4f700;
#   color: #000000;
# }
# #T_89d6a_row7_col1 {
#   background-color: #ff5d00;
#   color: #f1f1f1;
# }
# #T_89d6a_row8_col1 {
#   background-color: #ff2d00;
#   color: #f1f1f1;
# }
# #T_89d6a_row9_col1 {
#   background-color: #ff0900;
#   color: #f1f1f1;
# }
# #T_89d6a_row10_col1 {
#   background-color: #f40000;
#   color: #f1f1f1;
# }
# #T_89d6a_row11_col1 {
#   background-color: #d70000;
#   color: #f1f1f1;
# }
# #T_89d6a_row12_col1 {
#   background-color: #cf0000;
#   color: #f1f1f1;
# }
# #T_89d6a_row13_col1 {
#   background-color: #cc1c1c;
#   color: #f1f1f1;
# }
# #T_89d6a_row14_col1 {
#   background-color: #cc4c4c;
#   color: #f1f1f1;
# }
# #T_89d6a_row15_col1 {
#   background-color: #cc7c7c;
#   color: #f1f1f1;
# }
# #T_89d6a_row16_col1 {
#   background-color: #cc9c9c;
#   color: #f1f1f1;
# }
# #T_89d6a_row17_col1 {
#   background-color: #ccbcbc;
#   color: #000000;
# }
# #T_89d6a_row18_col1 {
#   background-color: #cccccc;
#   color: #000000;
# }
# </style>
# <table id="T_89d6a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_89d6a_level0_col0" class="col_heading level0 col0" >Words</th>
#       <th id="T_89d6a_level0_col1" class="col_heading level0 col1" >Counts</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_89d6a_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_89d6a_row0_col0" class="data row0 col0" >amp</td>
#       <td id="T_89d6a_row0_col1" class="data row0 col1" >268</td>
#     </tr>
#     <tr>
#       <th id="T_89d6a_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_89d6a_row1_col0" class="data row1 col0" >trump</td>
#       <td id="T_89d6a_row1_col1" class="data row1 col1" >197</td>
#     </tr>
#     <tr>
#       <th id="T_89d6a_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_89d6a_row2_col0" class="data row2 col0" >â¦</td>
#       <td id="T_89d6a_row2_col1" class="data row2 col1" >181</td>
#     </tr>
#     <tr>
#       <th id="T_89d6a_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_89d6a_row3_col0" class="data row3 col0" >libtard</td>
#       <td id="T_89d6a_row3_col1" class="data row3 col1" >149</td>
#     </tr>
#     <tr>
#       <th id="T_89d6a_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_89d6a_row4_col0" class="data row4 col0" >like</td>
#       <td id="T_89d6a_row4_col1" class="data row4 col1" >137</td>
#     </tr>
#     <tr>
#       <th id="T_89d6a_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_89d6a_row5_col0" class="data row5 col0" >white</td>
#       <td id="T_89d6a_row5_col1" class="data row5 col1" >137</td>
#     </tr>
#     <tr>
#       <th id="T_89d6a_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_89d6a_row6_col0" class="data row6 col0" >black</td>
#       <td id="T_89d6a_row6_col1" class="data row6 col1" >131</td>
#     </tr>
#     <tr>
#       <th id="T_89d6a_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_89d6a_row7_col0" class="data row7 col0" >racist</td>
#       <td id="T_89d6a_row7_col1" class="data row7 col1" >102</td>
#     </tr>
#     <tr>
#       <th id="T_89d6a_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_89d6a_row8_col0" class="data row8 col0" >people</td>
#       <td id="T_89d6a_row8_col1" class="data row8 col1" >99</td>
#     </tr>
#     <tr>
#       <th id="T_89d6a_level0_row9" class="row_heading level0 row9" >10</th>
#       <td id="T_89d6a_row9_col0" class="data row9 col0" >politics</td>
#       <td id="T_89d6a_row9_col1" class="data row9 col1" >96</td>
#     </tr>
#     <tr>
#       <th id="T_89d6a_level0_row10" class="row_heading level0 row10" >11</th>
#       <td id="T_89d6a_row10_col0" class="data row10 col0" >allahsoil</td>
#       <td id="T_89d6a_row10_col1" class="data row10 col1" >92</td>
#     </tr>
#     <tr>
#       <th id="T_89d6a_level0_row11" class="row_heading level0 row11" >12</th>
#       <td id="T_89d6a_row11_col0" class="data row11 col0" >liberal</td>
#       <td id="T_89d6a_row11_col1" class="data row11 col1" >82</td>
#     </tr>
#     <tr>
#       <th id="T_89d6a_level0_row12" class="row_heading level0 row12" >13</th>
#       <td id="T_89d6a_row12_col0" class="data row12 col0" >might</td>
#       <td id="T_89d6a_row12_col1" class="data row12 col1" >77</td>
#     </tr>
#     <tr>
#       <th id="T_89d6a_level0_row13" class="row_heading level0 row13" >14</th>
#       <td id="T_89d6a_row13_col0" class="data row13 col0" >sjw</td>
#       <td id="T_89d6a_row13_col1" class="data row13 col1" >74</td>
#     </tr>
#     <tr>
#       <th id="T_89d6a_level0_row14" class="row_heading level0 row14" >15</th>
#       <td id="T_89d6a_row14_col0" class="data row14 col0" >women</td>
#       <td id="T_89d6a_row14_col1" class="data row14 col1" >72</td>
#     </tr>
#     <tr>
#       <th id="T_89d6a_level0_row15" class="row_heading level0 row15" >16</th>
#       <td id="T_89d6a_row15_col0" class="data row15 col0" >new</td>
#       <td id="T_89d6a_row15_col1" class="data row15 col1" >69</td>
#     </tr>
#     <tr>
#       <th id="T_89d6a_level0_row16" class="row_heading level0 row16" >17</th>
#       <td id="T_89d6a_row16_col0" class="data row16 col0" >obama</td>
#       <td id="T_89d6a_row16_col1" class="data row16 col1" >68</td>
#     </tr>
#     <tr>
#       <th id="T_89d6a_level0_row17" class="row_heading level0 row17" >18</th>
#       <td id="T_89d6a_row17_col0" class="data row17 col0" >us</td>
#       <td id="T_89d6a_row17_col1" class="data row17 col1" >66</td>
#     </tr>
#     <tr>
#       <th id="T_89d6a_level0_row18" class="row_heading level0 row18" >19</th>
#       <td id="T_89d6a_row18_col0" class="data row18 col0" >hate</td>
#       <td id="T_89d6a_row18_col1" class="data row18 col1" >65</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Lemmatization
# Both stemming and lemmatization converts word to its base form. Stemming is a fast rule based technique and sometimes chops off inaccurately (under-stemming and over-stemming). You may have noticed NLTK provides PorterStemmer and a slightly improved Snowball Stemmer.
#
# Lemmatization is dictionary based technique, more accurate but slightly slower than stemming. We will use WordnetLemmatizer from NLTK. We will download the wordnet resource for this purpose.

# %%
lemmatizer = WordNetLemmatizer()

# %%
def lemmatize_word(word_list_without_sw):
    return [lemmatizer.lemmatize(word, pos = 'r') for word in word_list_without_sw]

# %%
train_df['Lemmatized_word'] = train_df['word_list_without_sw'].apply(lemmatize_word)

# %%
train_df.head(50)
# Out:
#                                                 tweet sentiment  \
# 0    @user when a father is dysfunctional and is s...  Positive
# 1   @user @user thanks for #lyft credit i can't us...  Positive
# 2                                 bihday your majesty  Positive
# 3   #model   i love u take with u all the time in ...  Positive
# 4              factsguide: society now    #motivation  Positive
# 5   [2/2] huge fan fare and big talking before the...  Positive
# 6    @user camping tomorrow @user @user @user @use...  Positive
# 7   the next school year is the year for exams.ð...  Positive
# 8   we won!!! love the land!!! #allin #cavs #champ...  Positive
# 9    @user @user welcome here !  i'm   it's so #gr...  Positive
# 10   â #ireland consumer price index (mom) climb...  Positive
# 11  we are so selfish. #orlando #standwithorlando ...  Positive
# 12  i get to see my daddy today!!   #80days #getti...  Positive
# 13  @user #cnn calls #michigan middle school 'buil...  Negative
# 14  no comment!  in #australia   #opkillingbay #se...  Negative
# 15  ouch...junior is angryð#got7 #junior #yugyo...  Positive
# 16  i am thankful for having a paner. #thankful #p...  Positive
# 17                             retweet if you agree!   Negative
# 18  its #friday! ð smiles all around via ig use...  Positive
# 19  as we all know, essential oils are not made of...  Positive
# 20  #euro2016 people blaming ha for conceded goal ...  Positive
# 21  sad little dude..   #badday #coneofshame #cats...  Positive
# 22  product of the day: happy man #wine tool  who'...  Positive
# 23    @user @user lumpy says i am a . prove it lumpy.  Negative
# 24   @user #tgif   #ff to my #gamedev #indiedev #i...  Positive
# 25  beautiful sign by vendor 80 for $45.00!! #upsi...  Positive
# 26   @user all #smiles when #media is   !! ðð...  Positive
# 27  we had a great panel on the mediatization of t...  Positive
# 28        happy father's day @user ðððð    Positive
# 29  50 people went to nightclub to have a good nig...  Positive
# 30  i have never had a chance to vote for a presid...  Positive
# 31    #alohafriday #time does #not #exist #positiv...  Positive
# 32   @user rip to the fellow nohern ireland fan wh...  Positive
# 33  it was a hard monday due to cloudy weather. di...  Positive
# 34  it's unbelievable that in the 21st century we'...  Negative
# 35  #taylorswift1989   bull up: you will dominate ...  Positive
# 36     morning~~ #travelingram #dalat   #ripinkylife   Positive
# 37  @user once more only one word tells it all: #p...  Positive
# 38  oh, #cedarpoint. waited 2 hours in the valravn...  Positive
# 39  i am thankful for sunshine. #thankful #positiv...  Positive
# 40  when you finally finish a book you've been wor...  Positive
# 41  yup, being a knicks fan is hard, so its easier...  Positive
# 42  there is life after social networking. embrace...  Positive
# 43  my mom shares the same bihday as @user   bihda...  Positive
# 44  lovely echeveria blooms#flowers #grow #gardeni...  Positive
# 45    i am amazing. #i_am #positive #affirmation       Positive
# 46  #model   i love u take with u all the time in ...  Positive
# 47     #whenever im   and #something goes #wrong  |    Positive
# 48                      feeling blue #illustration     Positive
# 49  the best pa about life is knowing who you are!...  Positive
#
#                                           clean_tweet  no_sentence  \
# 0   user when a father is dysfunctional and is so ...            2
# 1   user user thanks for lyft credit i cannot use ...            2
# 2                                 bihday your majesty            1
# 3   model i love you take with you all the time in...            2
# 4                   factsguide society now motivation            1
# 5    huge fan fare and big talking before they lea...            3
# 6   user camping tomorrow user user user user user...            1
# 7   the next school year is the year for examsð¯...            1
# 8   we won love the land allin cavs champions clev...            3
# 9             user user welcome here  i am it is so              2
# 10  â ireland consumer price index mom climbed f...            1
# 11  we are so selfish orlando standwithorlando pul...            2
# 12            i get to see my daddy today  gettingfed            2
# 13  user cnn calls michigan middle school build th...            1
# 14  no comment in australia opkillingbay seashephe...            2
# 15         ouchjunior is angryð junior yugyoem omg            1
# 16  i am thankful for having a paner thankful posi...            2
# 17                               retweet if you agree            1
# 18  its friday ð smiles all around via ig user ...            2
# 19  as we all know essential oils are not made of ...            1
# 20   people blaming ha for conceded goal was it fa...            1
# 21  sad little dude badday coneofshame cats pissed...            1
# 22  product of the day happy man wine tool who is ...            2
# 23        user user lumpy says i am a  prove it lumpy            2
# 24  user tgif ff to my gamedev indiedev indiegamed...            2
# 25  beautiful sign by vendor  for  upsideofflorida...            2
# 26  user all smiles when media is  ðð pressc...            5
# 27  we had a great panel on the mediatization of t...            1
# 28            happy fathers day user ðððð            1
# 29   people went to nightclub to have a good night...            1
# 30  i have never had a chance to vote for a presid...            1
# 31  alohafriday time does not exist positivevibes ...            1
# 32  user rip to the fellow nohern ireland fan who ...            2
# 33  it was a hard monday due to cloudy weather dis...            3
# 34  it is unbelievable that in the  century we wou...            3
# 35   bull up you will dominate your bull and you w...            2
# 36             morning travelingram dalat ripinkylife            1
# 37  user once more only one word tells it all phot...            2
# 38  oh cedarpoint waited  hours in the valravn lin...            3
# 39       i am thankful for sunshine thankful positive            2
# 40  when you finally finish a book you have been w...            1
# 41  yup being a knicks fan is hard so its easier t...            1
# 42  there is life after social networking embrace ...            3
# 43  my mom shares the same bihday as user bihday s...            2
# 44  lovely echeveria bloomsflowers grow gardening ...            1
# 45              i am amazing iam positive affirmation            2
# 46  model i love you take with you all the time in...            2
# 47            whenever i am and something goes wrong             1
# 48                          feeling blue illustration            1
# 49  the best pa about life is knowing who you are ...            2
#
#                                             word_list  \
# 0   [user, when, a, father, is, dysfunctional, and...
# 1   [user, user, thanks, for, lyft, credit, i, can...
# 2                             [bihday, your, majesty]
# 3   [model, i, love, you, take, with, you, all, th...
# 4              [factsguide, society, now, motivation]
# 5   [huge, fan, fare, and, big, talking, before, t...
# 6   [user, camping, tomorrow, user, user, user, us...
# 7   [the, next, school, year, is, the, year, for, ...
# 8   [we, won, love, the, land, allin, cavs, champi...
# 9      [user, user, welcome, here, i, am, it, is, so]
# 10  [â, ireland, consumer, price, index, mom, cl...
# 11  [we, are, so, selfish, orlando, standwithorlan...
# 12    [i, get, to, see, my, daddy, today, gettingfed]
# 13  [user, cnn, calls, michigan, middle, school, b...
# 14  [no, comment, in, australia, opkillingbay, sea...
# 15  [ouchjunior, is, angryð, junior, yugyoem, omg]
# 16  [i, am, thankful, for, having, a, paner, thank...
# 17                          [retweet, if, you, agree]
# 18  [its, friday, ð, smiles, all, around, via, ...
# 19  [as, we, all, know, essential, oils, are, not,...
# 20  [people, blaming, ha, for, conceded, goal, was...
# 21  [sad, little, dude, badday, coneofshame, cats,...
# 22  [product, of, the, day, happy, man, wine, tool...
# 23  [user, user, lumpy, says, i, am, a, prove, it,...
# 24  [user, tgif, ff, to, my, gamedev, indiedev, in...
# 25  [beautiful, sign, by, vendor, for, upsideofflo...
# 26  [user, all, smiles, when, media, is, ðð,...
# 27  [we, had, a, great, panel, on, the, mediatizat...
# 28      [happy, fathers, day, user, ðððð]
# 29  [people, went, to, nightclub, to, have, a, goo...
# 30  [i, have, never, had, a, chance, to, vote, for...
# 31  [alohafriday, time, does, not, exist, positive...
# 32  [user, rip, to, the, fellow, nohern, ireland, ...
# 33  [it, was, a, hard, monday, due, to, cloudy, we...
# 34  [it, is, unbelievable, that, in, the, century,...
# 35  [bull, up, you, will, dominate, your, bull, an...
# 36        [morning, travelingram, dalat, ripinkylife]
# 37  [user, once, more, only, one, word, tells, it,...
# 38  [oh, cedarpoint, waited, hours, in, the, valra...
# 39  [i, am, thankful, for, sunshine, thankful, pos...
# 40  [when, you, finally, finish, a, book, you, hav...
# 41  [yup, being, a, knicks, fan, is, hard, so, its...
# 42  [there, is, life, after, social, networking, e...
# 43  [my, mom, shares, the, same, bihday, as, user,...
# 44  [lovely, echeveria, bloomsflowers, grow, garde...
# 45       [i, am, amazing, iam, positive, affirmation]
# 46  [model, i, love, you, take, with, you, all, th...
# 47     [whenever, i, am, and, something, goes, wrong]
# 48                      [feeling, blue, illustration]
# 49  [the, best, pa, about, life, is, knowing, who,...
#
#                                  word_list_without_sw  \
# 0   [user, father, dysfunctional, selfish, drags, ...
# 1   [user, user, thanks, lyft, credit, use, offer,...
# 2                                   [bihday, majesty]
# 3   [model, love, take, time, areð±, ððð...
# 4                   [factsguide, society, motivation]
# 5   [huge, fan, fare, big, talking, leave, chaos, ...
# 6   [user, camping, tomorrow, user, user, user, us...
# 7   [next, school, year, year, examsð¯, think, ð...
# 8   [love, land, allin, cavs, champions, cleveland...
# 9                               [user, user, welcome]
# 10  [â, ireland, consumer, price, index, mom, cl...
# 11  [selfish, orlando, standwithorlando, pulseshoo...
# 12               [get, see, daddy, today, gettingfed]
# 13  [user, cnn, calls, michigan, middle, school, b...
# 14  [comment, australia, opkillingbay, seashepherd...
# 15      [ouchjunior, angryð, junior, yugyoem, omg]
# 16              [thankful, paner, thankful, positive]
# 17                                   [retweet, agree]
# 18  [friday, ð, smiles, around, via, ig, user, ...
# 19           [know, essential, oils, made, chemicals]
# 20  [people, blaming, ha, conceded, goal, fat, roo...
# 21  [sad, little, dude, badday, coneofshame, cats,...
# 22  [product, day, happy, man, wine, tool, weekend...
# 23            [user, user, lumpy, says, prove, lumpy]
# 24  [user, tgif, ff, gamedev, indiedev, indiegamed...
# 25  [beautiful, sign, vendor, upsideofflorida, sho...
# 26  [user, smiles, media, ðð, pressconferenc...
# 27     [great, panel, mediatization, public, service]
# 28      [happy, fathers, day, user, ðððð]
# 29  [people, went, nightclub, good, night, mans, a...
# 30  [never, chance, vote, presidential, candidate,...
# 31  [alohafriday, time, exist, positivevibes, hawa...
# 32  [user, rip, fellow, nohern, ireland, fan, sadl...
# 33  [hard, monday, due, cloudy, weather, disabling...
# 34  [unbelievable, century, would, need, something...
# 35  [bull, dominate, bull, direct, whatever, want, w]
# 36        [morning, travelingram, dalat, ripinkylife]
# 37  [user, one, word, tells, photoshop, enoughisen...
# 38  [oh, cedarpoint, waited, hours, valravn, line,...
# 39           [thankful, sunshine, thankful, positive]
# 40  [finally, finish, book, working, awhile, bookw...
# 41  [yup, knicks, fan, hard, easier, nba, fan, pla...
# 42           [life, social, networking, embrace, day]
# 43  [mom, shares, bihday, user, bihday, snake, see...
# 44  [lovely, echeveria, bloomsflowers, grow, garde...
# 45              [amazing, iam, positive, affirmation]
# 46  [model, love, take, time, areð±, ððð...
# 47                 [whenever, something, goes, wrong]
# 48                      [feeling, blue, illustration]
# 49  [best, pa, life, knowing, ðâï¸ð¼ð, »...
#
#                                       Lemmatized_word
# 0   [user, father, dysfunctional, selfish, drags, ...
# 1   [user, user, thanks, lyft, credit, use, offer,...
# 2                                   [bihday, majesty]
# 3   [model, love, take, time, areð±, ððð...
# 4                   [factsguide, society, motivation]
# 5   [huge, fan, fare, big, talking, leave, chaos, ...
# 6   [user, camping, tomorrow, user, user, user, us...
# 7   [next, school, year, year, examsð¯, think, ð...
# 8   [love, land, allin, cavs, champions, cleveland...
# 9                               [user, user, welcome]
# 10  [â, ireland, consumer, price, index, mom, cl...
# 11  [selfish, orlando, standwithorlando, pulseshoo...
# 12               [get, see, daddy, today, gettingfed]
# 13  [user, cnn, calls, michigan, middle, school, b...
# 14  [comment, australia, opkillingbay, seashepherd...
# 15      [ouchjunior, angryð, junior, yugyoem, omg]
# 16              [thankful, paner, thankful, positive]
# 17                                   [retweet, agree]
# 18  [friday, ð, smiles, around, via, ig, user, ...
# 19           [know, essential, oils, made, chemicals]
# 20  [people, blaming, ha, conceded, goal, fat, roo...
# 21  [sad, little, dude, badday, coneofshame, cats,...
# 22  [product, day, happy, man, wine, tool, weekend...
# 23            [user, user, lumpy, says, prove, lumpy]
# 24  [user, tgif, ff, gamedev, indiedev, indiegamed...
# 25  [beautiful, sign, vendor, upsideofflorida, sho...
# 26  [user, smiles, media, ðð, pressconferenc...
# 27     [great, panel, mediatization, public, service]
# 28      [happy, fathers, day, user, ðððð]
# 29  [people, went, nightclub, good, night, mans, a...
# 30  [never, chance, vote, presidential, candidate,...
# 31  [alohafriday, time, exist, positivevibes, hawa...
# 32  [user, rip, fellow, nohern, ireland, fan, sadl...
# 33  [hard, monday, due, cloudy, weather, disabling...
# 34  [unbelievable, century, would, need, something...
# 35  [bull, dominate, bull, direct, whatever, want, w]
# 36        [morning, travelingram, dalat, ripinkylife]
# 37  [user, one, word, tells, photoshop, enoughisen...
# 38  [oh, cedarpoint, waited, hours, valravn, line,...
# 39           [thankful, sunshine, thankful, positive]
# 40  [finally, finish, book, working, awhile, bookw...
# 41  [yup, knicks, fan, hard, easier, nba, fan, pla...
# 42           [life, social, networking, embrace, day]
# 43  [mom, shares, bihday, user, bihday, snake, see...
# 44  [lovely, echeveria, bloomsflowers, grow, garde...
# 45              [amazing, iam, positive, affirmation]
# 46  [model, love, take, time, areð±, ððð...
# 47                 [whenever, something, goes, wrong]
# 48                      [feeling, blue, illustration]
# 49  [best, pa, life, knowing, ðâï¸ð¼ð, »...

# %% [markdown]
#                                                         OR

# %%
train_df['Lemmatized_word'] = train_df['word_list_without_sw'].apply(lambda x: [lemmatizer.lemmatize(word) for word in x])

# %%
train_df.head(20)
# Out:
#                                                 tweet sentiment  \
# 0    @user when a father is dysfunctional and is s...  Positive
# 1   @user @user thanks for #lyft credit i can't us...  Positive
# 2                                 bihday your majesty  Positive
# 3   #model   i love u take with u all the time in ...  Positive
# 4              factsguide: society now    #motivation  Positive
# 5   [2/2] huge fan fare and big talking before the...  Positive
# 6    @user camping tomorrow @user @user @user @use...  Positive
# 7   the next school year is the year for exams.ð...  Positive
# 8   we won!!! love the land!!! #allin #cavs #champ...  Positive
# 9    @user @user welcome here !  i'm   it's so #gr...  Positive
# 10   â #ireland consumer price index (mom) climb...  Positive
# 11  we are so selfish. #orlando #standwithorlando ...  Positive
# 12  i get to see my daddy today!!   #80days #getti...  Positive
# 13  @user #cnn calls #michigan middle school 'buil...  Negative
# 14  no comment!  in #australia   #opkillingbay #se...  Negative
# 15  ouch...junior is angryð#got7 #junior #yugyo...  Positive
# 16  i am thankful for having a paner. #thankful #p...  Positive
# 17                             retweet if you agree!   Negative
# 18  its #friday! ð smiles all around via ig use...  Positive
# 19  as we all know, essential oils are not made of...  Positive
#
#                                           clean_tweet  no_sentence  \
# 0   user when a father is dysfunctional and is so ...            2
# 1   user user thanks for lyft credit i cannot use ...            2
# 2                                 bihday your majesty            1
# 3   model i love you take with you all the time in...            2
# 4                   factsguide society now motivation            1
# 5    huge fan fare and big talking before they lea...            3
# 6   user camping tomorrow user user user user user...            1
# 7   the next school year is the year for examsð¯...            1
# 8   we won love the land allin cavs champions clev...            3
# 9             user user welcome here  i am it is so              2
# 10  â ireland consumer price index mom climbed f...            1
# 11  we are so selfish orlando standwithorlando pul...            2
# 12            i get to see my daddy today  gettingfed            2
# 13  user cnn calls michigan middle school build th...            1
# 14  no comment in australia opkillingbay seashephe...            2
# 15         ouchjunior is angryð junior yugyoem omg            1
# 16  i am thankful for having a paner thankful posi...            2
# 17                               retweet if you agree            1
# 18  its friday ð smiles all around via ig user ...            2
# 19  as we all know essential oils are not made of ...            1
#
#                                             word_list  \
# 0   [user, when, a, father, is, dysfunctional, and...
# 1   [user, user, thanks, for, lyft, credit, i, can...
# 2                             [bihday, your, majesty]
# 3   [model, i, love, you, take, with, you, all, th...
# 4              [factsguide, society, now, motivation]
# 5   [huge, fan, fare, and, big, talking, before, t...
# 6   [user, camping, tomorrow, user, user, user, us...
# 7   [the, next, school, year, is, the, year, for, ...
# 8   [we, won, love, the, land, allin, cavs, champi...
# 9      [user, user, welcome, here, i, am, it, is, so]
# 10  [â, ireland, consumer, price, index, mom, cl...
# 11  [we, are, so, selfish, orlando, standwithorlan...
# 12    [i, get, to, see, my, daddy, today, gettingfed]
# 13  [user, cnn, calls, michigan, middle, school, b...
# 14  [no, comment, in, australia, opkillingbay, sea...
# 15  [ouchjunior, is, angryð, junior, yugyoem, omg]
# 16  [i, am, thankful, for, having, a, paner, thank...
# 17                          [retweet, if, you, agree]
# 18  [its, friday, ð, smiles, all, around, via, ...
# 19  [as, we, all, know, essential, oils, are, not,...
#
#                                  word_list_without_sw  \
# 0   [user, father, dysfunctional, selfish, drags, ...
# 1   [user, user, thanks, lyft, credit, use, offer,...
# 2                                   [bihday, majesty]
# 3   [model, love, take, time, areð±, ððð...
# 4                   [factsguide, society, motivation]
# 5   [huge, fan, fare, big, talking, leave, chaos, ...
# 6   [user, camping, tomorrow, user, user, user, us...
# 7   [next, school, year, year, examsð¯, think, ð...
# 8   [love, land, allin, cavs, champions, cleveland...
# 9                               [user, user, welcome]
# 10  [â, ireland, consumer, price, index, mom, cl...
# 11  [selfish, orlando, standwithorlando, pulseshoo...
# 12               [get, see, daddy, today, gettingfed]
# 13  [user, cnn, calls, michigan, middle, school, b...
# 14  [comment, australia, opkillingbay, seashepherd...
# 15      [ouchjunior, angryð, junior, yugyoem, omg]
# 16              [thankful, paner, thankful, positive]
# 17                                   [retweet, agree]
# 18  [friday, ð, smiles, around, via, ig, user, ...
# 19           [know, essential, oils, made, chemicals]
#
#                                       Lemmatized_word
# 0   [user, father, dysfunctional, selfish, drag, k...
# 1   [user, user, thanks, lyft, credit, use, offer,...
# 2                                   [bihday, majesty]
# 3   [model, love, take, time, areð±, ððð...
# 4                   [factsguide, society, motivation]
# 5   [huge, fan, fare, big, talking, leave, chaos, ...
# 6   [user, camping, tomorrow, user, user, user, us...
# 7   [next, school, year, year, examsð¯, think, ð...
# 8   [love, land, allin, cavs, champion, cleveland,...
# 9                               [user, user, welcome]
# 10  [â, ireland, consumer, price, index, mom, cl...
# 11  [selfish, orlando, standwithorlando, pulseshoo...
# 12               [get, see, daddy, today, gettingfed]
# 13  [user, cnn, call, michigan, middle, school, bu...
# 14  [comment, australia, opkillingbay, seashepherd...
# 15      [ouchjunior, angryð, junior, yugyoem, omg]
# 16              [thankful, paner, thankful, positive]
# 17                                   [retweet, agree]
# 18  [friday, ð, smile, around, via, ig, user, u...
# 19             [know, essential, oil, made, chemical]

# %% [markdown]
# ## Final pre-processing
# Let's to concatinate all the words in the last column on the dataframe and create a cleaned version of tweet text.

# %%
train_df['final_tweet'] = train_df['Lemmatized_word'].apply(lambda x:' '.join(x))

# %%
train_df.head(20)
# Out:
#                                                 tweet sentiment  \
# 0    @user when a father is dysfunctional and is s...  Positive
# 1   @user @user thanks for #lyft credit i can't us...  Positive
# 2                                 bihday your majesty  Positive
# 3   #model   i love u take with u all the time in ...  Positive
# 4              factsguide: society now    #motivation  Positive
# 5   [2/2] huge fan fare and big talking before the...  Positive
# 6    @user camping tomorrow @user @user @user @use...  Positive
# 7   the next school year is the year for exams.ð...  Positive
# 8   we won!!! love the land!!! #allin #cavs #champ...  Positive
# 9    @user @user welcome here !  i'm   it's so #gr...  Positive
# 10   â #ireland consumer price index (mom) climb...  Positive
# 11  we are so selfish. #orlando #standwithorlando ...  Positive
# 12  i get to see my daddy today!!   #80days #getti...  Positive
# 13  @user #cnn calls #michigan middle school 'buil...  Negative
# 14  no comment!  in #australia   #opkillingbay #se...  Negative
# 15  ouch...junior is angryð#got7 #junior #yugyo...  Positive
# 16  i am thankful for having a paner. #thankful #p...  Positive
# 17                             retweet if you agree!   Negative
# 18  its #friday! ð smiles all around via ig use...  Positive
# 19  as we all know, essential oils are not made of...  Positive
#
#                                           clean_tweet  no_sentence  \
# 0   user when a father is dysfunctional and is so ...            2
# 1   user user thanks for lyft credit i cannot use ...            2
# 2                                 bihday your majesty            1
# 3   model i love you take with you all the time in...            2
# 4                   factsguide society now motivation            1
# 5    huge fan fare and big talking before they lea...            3
# 6   user camping tomorrow user user user user user...            1
# 7   the next school year is the year for examsð¯...            1
# 8   we won love the land allin cavs champions clev...            3
# 9             user user welcome here  i am it is so              2
# 10  â ireland consumer price index mom climbed f...            1
# 11  we are so selfish orlando standwithorlando pul...            2
# 12            i get to see my daddy today  gettingfed            2
# 13  user cnn calls michigan middle school build th...            1
# 14  no comment in australia opkillingbay seashephe...            2
# 15         ouchjunior is angryð junior yugyoem omg            1
# 16  i am thankful for having a paner thankful posi...            2
# 17                               retweet if you agree            1
# 18  its friday ð smiles all around via ig user ...            2
# 19  as we all know essential oils are not made of ...            1
#
#                                             word_list  \
# 0   [user, when, a, father, is, dysfunctional, and...
# 1   [user, user, thanks, for, lyft, credit, i, can...
# 2                             [bihday, your, majesty]
# 3   [model, i, love, you, take, with, you, all, th...
# 4              [factsguide, society, now, motivation]
# 5   [huge, fan, fare, and, big, talking, before, t...
# 6   [user, camping, tomorrow, user, user, user, us...
# 7   [the, next, school, year, is, the, year, for, ...
# 8   [we, won, love, the, land, allin, cavs, champi...
# 9      [user, user, welcome, here, i, am, it, is, so]
# 10  [â, ireland, consumer, price, index, mom, cl...
# 11  [we, are, so, selfish, orlando, standwithorlan...
# 12    [i, get, to, see, my, daddy, today, gettingfed]
# 13  [user, cnn, calls, michigan, middle, school, b...
# 14  [no, comment, in, australia, opkillingbay, sea...
# 15  [ouchjunior, is, angryð, junior, yugyoem, omg]
# 16  [i, am, thankful, for, having, a, paner, thank...
# 17                          [retweet, if, you, agree]
# 18  [its, friday, ð, smiles, all, around, via, ...
# 19  [as, we, all, know, essential, oils, are, not,...
#
#                                  word_list_without_sw  \
# 0   [user, father, dysfunctional, selfish, drags, ...
# 1   [user, user, thanks, lyft, credit, use, offer,...
# 2                                   [bihday, majesty]
# 3   [model, love, take, time, areð±, ððð...
# 4                   [factsguide, society, motivation]
# 5   [huge, fan, fare, big, talking, leave, chaos, ...
# 6   [user, camping, tomorrow, user, user, user, us...
# 7   [next, school, year, year, examsð¯, think, ð...
# 8   [love, land, allin, cavs, champions, cleveland...
# 9                               [user, user, welcome]
# 10  [â, ireland, consumer, price, index, mom, cl...
# 11  [selfish, orlando, standwithorlando, pulseshoo...
# 12               [get, see, daddy, today, gettingfed]
# 13  [user, cnn, calls, michigan, middle, school, b...
# 14  [comment, australia, opkillingbay, seashepherd...
# 15      [ouchjunior, angryð, junior, yugyoem, omg]
# 16              [thankful, paner, thankful, positive]
# 17                                   [retweet, agree]
# 18  [friday, ð, smiles, around, via, ig, user, ...
# 19           [know, essential, oils, made, chemicals]
#
#                                       Lemmatized_word  \
# 0   [user, father, dysfunctional, selfish, drag, k...
# 1   [user, user, thanks, lyft, credit, use, offer,...
# 2                                   [bihday, majesty]
# 3   [model, love, take, time, areð±, ððð...
# 4                   [factsguide, society, motivation]
# 5   [huge, fan, fare, big, talking, leave, chaos, ...
# 6   [user, camping, tomorrow, user, user, user, us...
# 7   [next, school, year, year, examsð¯, think, ð...
# 8   [love, land, allin, cavs, champion, cleveland,...
# 9                               [user, user, welcome]
# 10  [â, ireland, consumer, price, index, mom, cl...
# 11  [selfish, orlando, standwithorlando, pulseshoo...
# 12               [get, see, daddy, today, gettingfed]
# 13  [user, cnn, call, michigan, middle, school, bu...
# 14  [comment, australia, opkillingbay, seashepherd...
# 15      [ouchjunior, angryð, junior, yugyoem, omg]
# 16              [thankful, paner, thankful, positive]
# 17                                   [retweet, agree]
# 18  [friday, ð, smile, around, via, ig, user, u...
# 19             [know, essential, oil, made, chemical]
#
#                                           final_tweet
# 0   user father dysfunctional selfish drag kid dys...
# 1   user user thanks lyft credit use offer wheelch...
# 2                                      bihday majesty
# 3   model love take time areð± ðððð ð...
# 4                       factsguide society motivation
# 5   huge fan fare big talking leave chaos pay disp...
# 6   user camping tomorrow user user user user user...
# 7   next school year year examsð¯ think ð­ sch...
# 8   love land allin cavs champion cleveland clevel...
# 9                                   user user welcome
# 10  â ireland consumer price index mom climbed p...
# 11  selfish orlando standwithorlando pulseshooting...
# 12                     get see daddy today gettingfed
# 13  user cnn call michigan middle school build wal...
# 14  comment australia opkillingbay seashepherd hel...
# 15            ouchjunior angryð junior yugyoem omg
# 16                   thankful paner thankful positive
# 17                                      retweet agree
# 18  friday ð smile around via ig user user cook...
# 19                   know essential oil made chemical
